# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
import pandas as pd

# %%
from pandas import DataFrame

# %% [markdown]
# creating dataframe object

# %%
bank=pd.read_csv('/content/gdrive/MyDrive/principle data science lab/banks.csv')
bank.head()
# Out:
#    age         job  marital  education fault  balance housing loan  contact  \
# 0   59      admin.  married  secondary    no     2343     yes   no  unknown
# 1   56      admin.  married  secondary    no       45      no   no  unknown
# 2   41  technician  married  secondary    no     1270     yes   no  unknown
# 3   55    services  married  secondary    no     2476     yes   no  unknown
# 4   54      admin.  married   tertiary    no      184      no   no  unknown
#
#    day month  duration  campaign  pdays  previous poutcome deposit
# 0    5   may      1042         1     -1         0  unknown     yes
# 1    5   may      1467         1     -1         0  unknown     yes
# 2    5   may      1389         1     -1         0  unknown     yes
# 3    5   may       579         1     -1         0  unknown     yes
# 4    5   may       673         2     -1         0  unknown     yes

# %%
bank=pd.read_('/content/gdrive/MyDrive/principle data science lab/banks.csv')
bank.head()

# %%
bank=pd.read_csv('/content/gdrive/MyDrive/principle data science lab/banks.csv')
bank
# Out:
#        age          job  marital  education fault  balance housing loan  \
# 0       59       admin.  married  secondary    no     2343     yes   no
# 1       56       admin.  married  secondary    no       45      no   no
# 2       41   technician  married  secondary    no     1270     yes   no
# 3       55     services  married  secondary    no     2476     yes   no
# 4       54       admin.  married   tertiary    no      184      no   no
# ...    ...          ...      ...        ...   ...      ...     ...  ...
# 11157   33  blue-collar   single    primary    no        1     yes   no
# 11158   39     services  married  secondary    no      733      no   no
# 11159   32   technician   single  secondary    no       29      no   no
# 11160   43   technician  married  secondary    no        0      no  yes
# 11161   34   technician  married  secondary    no        0      no   no
#
#         contact  day month  duration  campaign  pdays  previous poutcome  \
# ...

# %% [markdown]
# confirming data frame

# %%
bank.shape
# Out:
# (11162, 17)

# %%
bank.describe()
# Out:
#                 age       balance           day      duration      campaign  \
# count  11162.000000  11162.000000  11162.000000  11162.000000  11162.000000
# mean      41.231948   1528.538524     15.658036    371.993818      2.508421
# std       11.913369   3225.413326      8.420740    347.128386      2.722077
# min       18.000000  -6847.000000      1.000000      2.000000      1.000000
# 25%       32.000000    122.000000      8.000000    138.000000      1.000000
# 50%       39.000000    550.000000     15.000000    255.000000      2.000000
# 75%       49.000000   1708.000000     22.000000    496.000000      3.000000
# max       95.000000  81204.000000     31.000000   3881.000000     63.000000
#
#               pdays      previous
# count  11162.000000  11162.000000
# mean      51.330407      0.832557
# std      108.758282      2.292007
# min       -1.000000      0.000000
# 25%       -1.000000      0.000000
# 50%       -1.000000      0.000000
# 75%       20.750000      1.000000
# ...

# %%
bank.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11162 entries, 0 to 11161
# Data columns (total 17 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   age        11162 non-null  int64
#  1   job        11162 non-null  object
#  2   marital    11162 non-null  object
#  3   education  11162 non-null  object
#  4   fault      11162 non-null  object
#  5   balance    11162 non-null  int64
#  6   housing    11162 non-null  object
#  7   loan       11162 non-null  object
#  8   contact    11162 non-null  object
#  9   day        11162 non-null  int64
#  10  month      11162 non-null  object
#  11  duration   11162 non-null  int64
#  12  campaign   11162 non-null  int64
#  13  pdays      11162 non-null  int64
#  14  previous   11162 non-null  int64
#  15  poutcome   11162 non-null  object
#  16  deposit    11162 non-null  object
# dtypes: int64(7), object(10)
# memory usage: 1.4+ MB

# %% [markdown]
# converting string to categories

# %%
bank['marital'].astype('category')
# Out:
# 0        married
# 1        married
# 2        married
# 3        married
# 4        married
#           ...
# 11157     single
# 11158    married
# 11159     single
# 11160    married
# 11161    married
# Name: marital, Length: 11162, dtype: category
# Categories (3, object): ['divorced', 'married', 'single']

# %%
bank['marital']=bank['marital'].astype('category')
bank[	'balance']=bank['balance'].astype('category')

# %%
bank.describe(include='category')
# Out:
#         marital  balance  pdays
# count     11162    11162  11162
# unique        3     3805    472
# top     married        0     -1
# freq       6351      774   8324

# %% [markdown]
# type conversion using programming constructs

# %%
for col in['marital','balance']:
  bank[col]=bank[col].astype('category')
  bank.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11162 entries, 0 to 11161
# Data columns (total 17 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   age        11162 non-null  int64
#  1   job        11162 non-null  object
#  2   marital    11162 non-null  category
#  3   education  11162 non-null  object
#  4   fault      11162 non-null  object
#  5   balance    11162 non-null  category
#  6   housing    11162 non-null  object
#  7   loan       11162 non-null  object
#  8   contact    11162 non-null  object
#  9   day        11162 non-null  int64
#  10  month      11162 non-null  object
#  11  duration   11162 non-null  int64
#  12  campaign   11162 non-null  int64
#  13  pdays      11162 non-null  category
#  14  previous   11162 non-null  int64
#  15  poutcome   11162 non-null  object
#  16  deposit    11162 non-null  object
# dtypes: category(3), int64(5), object(9)
# memory usage: 1.4+ MB
# <class 'pandas.core.frame.DataFrame'>
# ...

# %% [markdown]
# basic visualization

# %%
bank['duration'].mean()
# Out:
# 371.99381831213043

# %%
dur=bank['duration']

# %%
dur.min(),dur.mean(),dur.median(),dur.max()
# Out:
# (2, 371.99381831213043, 255.0, 3881)

# %%
bank.describe()
# Out:
#                 age           day      duration      campaign      previous
# count  11162.000000  11162.000000  11162.000000  11162.000000  11162.000000
# mean      41.231948     15.658036    371.993818      2.508421      0.832557
# std       11.913369      8.420740    347.128386      2.722077      2.292007
# min       18.000000      1.000000      2.000000      1.000000      0.000000
# 25%       32.000000      8.000000    138.000000      1.000000      0.000000
# 50%       39.000000     15.000000    255.000000      2.000000      0.000000
# 75%       49.000000     22.000000    496.000000      3.000000      1.000000
# max       95.000000     31.000000   3881.000000     63.000000     58.000000

# %% [markdown]
# histogram
# loading the libraries

# %%
import seaborn as sns

# %% [markdown]
# creating histogram

# %%
sns.histplot(x=bank['month'],bins=10,kde=True);

# %%
sns.histplot(x=bank['duration'],bins=10,kde=False,stat="probability",color='Pink');

# %% [markdown]
# filtering data

# %%
import pandas as  pd
bank=pd.read_csv('/content/gdrive/MyDrive/principle data science lab/banks.csv')

# %% [markdown]
# boolean vector

# %%
bank['marital']=='single'
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 11157     True
# 11158    False
# 11159     True
# 11160    False
# 11161    False
# Name: marital, Length: 11162, dtype: bool

# %%
bank[bank['marital']=="single"]
# Out:
#        age            job marital  education fault  balance housing loan  \
# 5       42     management  single   tertiary    no        0     yes  yes
# 9       28       services  single  secondary    no     5090     yes   no
# 10      38         admin.  single  secondary    no      100     yes   no
# 13      46    blue-collar  single   tertiary    no      460     yes   no
# 14      31     technician  single   tertiary    no      703     yes   no
# ...    ...            ...     ...        ...   ...      ...     ...  ...
# 11139   30  self-employed  single   tertiary    no     2593      no   no
# 11153   43         admin.  single  secondary    no       35      no   no
# 11156   34    blue-collar  single  secondary    no      -72     yes   no
# 11157   33    blue-collar  single    primary    no        1     yes   no
# 11159   32     technician  single  secondary    no       29      no   no
#
#          contact  day month  duration  campaign  pdays  previous poutcome  \
# ...

# %%
singleEmployees=bank[bank['marital']=="Female"]
type(singleEmployees)
# Out:
# pandas.core.frame.DataFrame

# %%
singleEmployees['duration'].mean()
# Out:
# nan

# %%
round(singleEmployees['balance'].mean(),2)
# Out:
# nan

# %% [markdown]
# complex filtering creteria

# %%
(bank['marital']=='married')&(bank['job']==1)
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 11157    False
# 11158    False
# 11159    False
# 11160    False
# 11161    False
# Length: 11162, dtype: bool

# %%
bank[(bank['marital']=='married')&(bank['job']==1)].shape
# Out:
# (0, 17)

# %% [markdown]
# filtering by a list

# %%
bank[bank['campaign']>=4]
# Out:
#        age            job   marital  education fault  balance housing loan  \
# 12      29     management   married   tertiary    no      199     yes  yes
# 25      35    blue-collar    single  secondary    no       40     yes   no
# 36      35    blue-collar   married    primary    no      414      no   no
# 38      38     management   married   tertiary    no      119     yes   no
# 43      36    blue-collar   married  secondary    no     1165     yes   no
# ...    ...            ...       ...        ...   ...      ...     ...  ...
# 11139   30  self-employed    single   tertiary    no     2593      no   no
# 11140   55       services  divorced  secondary    no     2166     yes   no
# 11147   44     unemployed   married  secondary    no        0      no   no
# 11156   34    blue-collar    single  secondary    no      -72     yes   no
# 11158   39       services   married  secondary    no      733      no   no
#
# ...

# %%
mgmt=[4,5,6]
bank[bank['campaign'].isin(mgmt)]
# Out:
#        age          job   marital  education fault  balance housing loan  \
# 12      29   management   married   tertiary    no      199     yes  yes
# 25      35  blue-collar    single  secondary    no       40     yes   no
# 36      35  blue-collar   married    primary    no      414      no   no
# 38      38   management   married   tertiary    no      119     yes   no
# 43      36  blue-collar   married  secondary    no     1165     yes   no
# ...    ...          ...       ...        ...   ...      ...     ...  ...
# 11125   40  blue-collar  divorced    primary    no       54     yes   no
# 11138   32   technician   married  secondary    no      235     yes   no
# 11147   44   unemployed   married  secondary    no        0      no   no
# 11156   34  blue-collar    single  secondary    no      -72     yes   no
# 11158   39     services   married  secondary    no      733      no   no
#
#          contact  day month  duration  campaign  pdays  previous poutcome  \
# ...
