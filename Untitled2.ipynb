# %%
import matplotlib.pyplot as plt

# %%
plt.plot([1,2,3,4])
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
x=np.arange(0,5,0.01)
plt.plot(x,[i**2 for i in x])
plt.show()
