# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
from io import IncrementalNewlineDecoder
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
sns.set(color_codes=True)

# %%
student=pd.read_csv('/content/drive/MyDrive/principle data science lab/student.csv')
student
# Out:
#    stud_ID    stud_name Department  Physics  Mathematics  Computer Sci.  \
# 0       S1       Sonali        MSc       88         73.0           66.0
# 1       S2        Veena        MSc       89         81.0           78.0
# 2       S3      Gautham        MSc       68         89.0           55.0
# 3       S4       Sonith        MSc       90         71.0            NaN
# 4       S5     Siddarth        MSc       56         90.0           88.0
# 5       S6        Isana        MSc       44         45.0           90.0
# 6       S7         Hifa        MSc       34         33.0           84.0
# 7       S8      Prathvi        MSc       89         34.0           67.0
# 8       S9     Dhanvika        MSc       63         56.0           72.0
# 9      S10  Jayalakshmi        MCA       12         71.0           92.0
# 10     S11      Jithesh        MCA       66         67.0           66.0
# 11     S12       Manavi        MCA       48         83.0           93.0
# ...

# %%
student.head()
# Out:
#   stud_ID stud_name Department  Physics  Mathematics  Computer Sci.  \
# 0      S1    Sonali        MSc       88         73.0           66.0
# 1      S2     Veena        MSc       89         81.0           78.0
# 2      S3   Gautham        MSc       68         89.0           55.0
# 3      S4    Sonith        MSc       90         71.0            NaN
# 4      S5  Siddarth        MSc       56         90.0           88.0
#
#    Total Score
# 0          227
# 1          248
# 2          212
# 3          161
# 4          234

# %%
student.tail(6)
# Out:
#    stud_ID   stud_name Department  Physics  Mathematics  Computer Sci.  \
# 14     S15    Sushanth        MCA       94         71.0           89.0
# 15     S16      Sandya        MCA       89         77.0           49.0
# 16     S17  Subramanya        MCA       66         78.0           88.0
# 17     S18       Pooja        MCA       73          NaN           96.0
# 18     S19   Harshitha        MCA       19         78.0           88.0
# 19     S20    Thriveni        MCA       52         55.0           95.0
#
#     Total Score
# 14          254
# 15          215
# 16          232
# 17          169
# 18          185
# 19          202

# %%
student.describe(include='all')
# Out:
#        stud_ID stud_name Department    Physics  Mathematics  Computer Sci.  \
# count       20        20         20  20.000000    19.000000      18.000000
# unique      20        20          2        NaN          NaN            NaN
# top         S1    Sonali        MCA        NaN          NaN            NaN
# freq         1         1         11        NaN          NaN            NaN
# mean       NaN       NaN        NaN  64.550000    63.894737      80.222222
# std        NaN       NaN        NaN  24.132256    20.140878      14.268664
# min        NaN       NaN        NaN  12.000000    29.000000      49.000000
# 25%        NaN       NaN        NaN  51.000000    50.000000      68.250000
# 50%        NaN       NaN        NaN  66.000000    71.000000      88.000000
# 75%        NaN       NaN        NaN  88.250000    78.000000      89.750000
# max        NaN       NaN        NaN  94.000000    90.000000      96.000000
#
#         Total Score
# count     20.000000
# unique          NaN
# ...

# %%
student.hist(figsize=(20,20))
# Out:
# array([[<Axes: title={'center': 'Physics'}>,
#         <Axes: title={'center': 'Mathematics'}>],
#        [<Axes: title={'center': 'Computer Sci.'}>,
#         <Axes: title={'center': 'Total Score'}>]], dtype=object)

# %%
sns.boxplot(x="Physics",y="Mathematics",data=student)
# Out:
# <Axes: xlabel='Physics', ylabel='Mathematics'>

# %%
sns.pairplot(student)

# %%
print(student.isnull().sum())
# Out:
# stud_ID          0
# stud_name        0
# Department       0
# Physics          0
# Mathematics      1
# Computer Sci.    2
# Total Score      0
# dtype: int64

# %%
student=student.dropna()
student.count()
# Out:
# stud_ID          17
# stud_name        17
# Department       17
# Physics          17
# Mathematics      17
# Computer Sci.    17
# Total Score      17
# dtype: int64

# %%
student=student.rename(columns={"Department":"dept"})
student.head(6)
# Out:
#   stud_ID stud_name dept  Physics  Mathematics  Computer Sci.  Total Score
# 0      S1    Sonali  MSc       88         73.0           66.0          227
# 1      S2     Veena  MSc       89         81.0           78.0          248
# 2      S3   Gautham  MSc       68         89.0           55.0          212
# 4      S5  Siddarth  MSc       56         90.0           88.0          234
# 5      S6     Isana  MSc       44         45.0           90.0          179
# 6      S7      Hifa  MSc       34         33.0           84.0          151

# %%
student['Physics'].mean()
# Out:
# 61.35294117647059

# %%
import statistics
Physics=[88,89,68,56,44,34]
print("The average of student values is:",end="")
print(statistics.mean(Physics))
# Out:
# The average of student values is:63.166666666666664

# %%
student.mean
# Out:
# <bound method NDFrame._add_numeric_operations.<locals>.mean of    stud_ID    stud_name dept  Physics  Mathematics  Computer Sci.  Total Score
# 0       S1       Sonali  MSc       88         73.0           66.0          227
# 1       S2        Veena  MSc       89         81.0           78.0          248
# 2       S3      Gautham  MSc       68         89.0           55.0          212
# 4       S5     Siddarth  MSc       56         90.0           88.0          234
# 5       S6        Isana  MSc       44         45.0           90.0          179
# 6       S7         Hifa  MSc       34         33.0           84.0          151
# 7       S8      Prathvi  MSc       89         34.0           67.0          190
# 8       S9     Dhanvika  MSc       63         56.0           72.0          191
# 9      S10  Jayalakshmi  MCA       12         71.0           92.0          175
# 10     S11      Jithesh  MCA       66         67.0           66.0          199
# ...

# %%
student['Total Score'].median
# Out:
# <bound method NDFrame._add_numeric_operations.<locals>.median of 0     227
# 1     248
# 2     212
# 4     234
# 5     179
# 6     151
# 7     190
# 8     191
# 9     175
# 10    199
# 11    224
# 13    187
# 14    254
# 15    215
# 16    232
# 18    185
# 19    202
# Name: Total Score, dtype: int64>

# %%
student.median
# Out:
# <bound method NDFrame._add_numeric_operations.<locals>.median of    stud_ID    stud_name dept  Physics  Mathematics  Computer Sci.  Total Score
# 0       S1       Sonali  MSc       88         73.0           66.0          227
# 1       S2        Veena  MSc       89         81.0           78.0          248
# 2       S3      Gautham  MSc       68         89.0           55.0          212
# 4       S5     Siddarth  MSc       56         90.0           88.0          234
# 5       S6        Isana  MSc       44         45.0           90.0          179
# 6       S7         Hifa  MSc       34         33.0           84.0          151
# 7       S8      Prathvi  MSc       89         34.0           67.0          190
# 8       S9     Dhanvika  MSc       63         56.0           72.0          191
# 9      S10  Jayalakshmi  MCA       12         71.0           92.0          175
# 10     S11      Jithesh  MCA       66         67.0           66.0          199
# ...

# %%
student['Physics'].mode
# Out:
# <bound method Series.mode of 0     88
# 1     89
# 2     68
# 4     56
# 5     44
# 6     34
# 7     89
# 8     63
# 9     12
# 10    66
# 11    48
# 13    66
# 14    94
# 15    89
# 16    66
# 18    19
# 19    52
# Name: Physics, dtype: int64>

# %%
student.Physics.value_counts().nlargest(40).plot(kind="bar",figsize=(10,7))
plt.title("Number of students bbby physics")
plt.ylabel("Number of students")
plt.xlabel("Physics");

# %%
plt.figure(figsize=(20,10))
r=student.corr()
sns.heatmap(r,cmap="BrBG",annot=True)
r
# Out:
# <ipython-input-32-c82112523b8d>:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   r=student.corr()
#                 Physics  Mathematics  Computer Sci.  Total Score
# Physics        1.000000     0.063699      -0.553618     0.648152
# Mathematics    0.063699     1.000000      -0.143665     0.676494
# Computer Sci. -0.553618    -0.143665       1.000000    -0.082798
# Total Score    0.648152     0.676494      -0.082798     1.000000
